# %% [markdown]
# # Zipline Installation: Bundle Ingest & Algorithm Test

# %% [markdown]
# ## Imports and Settings

# %% [markdown]
# We don't need much here since the imports all take place in the cell where we formulate the algorithm.

# %%
# %matplotlib inline

# %%
import os
os.environ["QUANDL_API_KEY"] = "a46TmtNy3DB9htxAs7TS"

# %% [markdown]
# ## Load Zipline extension

# %%
# %load_ext zipline

# %%
# %reload_ext zipline

# %% [markdown]
# ## Ingest Data

# %%
# !zipline ingest -b quandl
# Out:
# Downloading WIKI Prices table from Quandl
# Merging daily equity files:
# [2023-11-27T19:14:16+0100-INFO][zipline.data.bundles.core]
#  Ingesting quandl
# [2023-11-27T19:14:16+0100-INFO][zipline.data.bundles.quandl]
#  Downloading WIKI metadata.
# [2023-11-27T19:14:43+0100-INFO][zipline.data.bundles.quandl]
#  Parsing raw data.
# [2023-11-27T19:15:08+0100-INFO][zipline.data.bundles.quandl]
#  Generating asset metadata.
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\bundles\quandl.py:106: FutureWarning: The provided callable <function min at 0x000001EC7C418DC0> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   data = data.groupby(by="symbol").agg({"date": [np.min, np.max]})
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\bundles\quandl.py:106: FutureWarning: The provided callable <function max at 0x000001EC7C418CA0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   data = data.groupby(by="symbol").agg({"date": [np.min, np.max]})
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\bcolz_daily_bars.py:341: UserWarning: Ignoring 1 values because they are out of bounds for uint32:
#              open  high   low  close        volume  ex_dividend  split_ratio
# 2011-04-11  1.79  1.84  1.55    1.7  6.674913e+09          0.0          1.0
#   winsorise_uint32(raw_data, invalid_data_behavior, "volume", *OHLC)
# [2023-11-27T19:16:22+0100-INFO][zipline.data.bundles.quandl]
#  Parsing split data.
# [2023-11-27T19:16:22+0100-INFO][zipline.data.bundles.quandl]
#  Parsing dividend data.
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=67, ex_date=2017-11-09, amount=0.620
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=93, ex_date=2017-11-09, amount=0.240
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=161, ex_date=2017-11-09, amount=0.110
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=283, ex_date=2017-11-09, amount=0.415
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=298, ex_date=2017-11-09, amount=1.420
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=318, ex_date=2017-11-09, amount=0.330
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=434, ex_date=2017-11-09, amount=0.110
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=516, ex_date=1996-05-30, amount=0.310
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=524, ex_date=2017-11-09, amount=0.050
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=556, ex_date=2017-11-09, amount=0.075
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=578, ex_date=2017-11-09, amount=0.160
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=605, ex_date=2017-11-09, amount=0.040
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=666, ex_date=1990-03-26, amount=0.140
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=694, ex_date=1990-03-27, amount=0.100
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=723, ex_date=2017-11-09, amount=1.620
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=758, ex_date=2017-11-09, amount=0.500
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=788, ex_date=2017-11-09, amount=0.060
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=859, ex_date=1995-05-09, amount=0.100
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=904, ex_date=2017-11-09, amount=0.135
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=975, ex_date=2017-11-09, amount=0.030
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=1057, ex_date=2017-11-09, amount=0.250
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=1088, ex_date=1990-03-26, amount=0.240
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=1091, ex_date=2017-11-09, amount=0.075
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=1111, ex_date=1993-03-04, amount=0.070
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=1172, ex_date=2017-11-09, amount=0.130
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=1209, ex_date=2017-11-09, amount=0.010
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=1322, ex_date=1995-05-25, amount=0.150
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=1441, ex_date=2017-11-09, amount=1.500
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=1525, ex_date=2017-11-09, amount=0.090
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=1600, ex_date=2015-07-06, amount=16.500
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=1642, ex_date=2017-11-09, amount=0.270
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=1748, ex_date=2017-11-09, amount=0.740
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=1876, ex_date=2017-11-09, amount=0.120
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=1922, ex_date=2017-11-09, amount=0.040
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=1947, ex_date=1990-03-26, amount=0.150
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2098, ex_date=2017-11-09, amount=0.200
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2118, ex_date=2014-11-06, amount=0.050
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2120, ex_date=2017-11-09, amount=0.110
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2149, ex_date=2017-11-09, amount=0.330
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2204, ex_date=2017-11-09, amount=0.320
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2220, ex_date=2017-11-09, amount=0.660
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2281, ex_date=2017-11-09, amount=0.450
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2389, ex_date=2017-11-09, amount=0.140
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2441, ex_date=2017-11-09, amount=0.215
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2517, ex_date=2017-11-09, amount=0.080
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2582, ex_date=2017-11-09, amount=0.780
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2622, ex_date=2017-11-09, amount=0.390
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2662, ex_date=2015-01-14, amount=0.750
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2754, ex_date=2000-12-27, amount=0.250
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2754, ex_date=2009-09-11, amount=0.420
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2754, ex_date=2009-12-11, amount=0.420
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2754, ex_date=2010-03-11, amount=0.420
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2754, ex_date=2010-12-15, amount=0.180
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2766, ex_date=2017-11-09, amount=0.320
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2798, ex_date=2017-11-09, amount=0.065
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2817, ex_date=1992-03-03, amount=0.300
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2824, ex_date=2017-11-09, amount=0.120
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2843, ex_date=2017-11-09, amount=0.150
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2857, ex_date=2011-09-07, amount=0.410
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=2968, ex_date=1990-03-26, amount=0.100
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=3005, ex_date=1990-03-26, amount=0.070
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=3078, ex_date=2014-05-12, amount=0.060
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=3117, ex_date=2017-11-09, amount=0.430
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=3138, ex_date=2010-08-16, amount=0.060
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Couldn't compute ratio for dividend sid=3145, ex_date=2017-11-09, amount=0.050
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Dividend ratio <= 0 for dividend sid=501, ex_date=2006-01-03, amount=41.560
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Dividend ratio <= 0 for dividend sid=1557, ex_date=2007-07-02, amount=88.530
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Dividend ratio <= 0 for dividend sid=1632, ex_date=2000-07-13, amount=181.000
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Dividend ratio <= 0 for dividend sid=1657, ex_date=2013-09-30, amount=21.355
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Dividend ratio <= 0 for dividend sid=1775, ex_date=1994-12-01, amount=76.000
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Dividend ratio <= 0 for dividend sid=1776, ex_date=1996-11-04, amount=36.708
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Dividend ratio <= 0 for dividend sid=2455, ex_date=2016-10-03, amount=25.611
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Dividend ratio <= 0 for dividend sid=2687, ex_date=2008-06-26, amount=10.000
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Dividend ratio <= 0 for dividend sid=2900, ex_date=2007-07-02, amount=88.530
# [2023-11-27T19:16:25+0100-WARNING][zipline.data.adjustments]
#  Dividend ratio <= 0 for dividend sid=3088, ex_date=2015-04-27, amount=31.291
# [2023-11-27T19:16:25+0100-INFO][root]
#  copying C:\Users\justu\AppData\Local\Temp\tmppz6poify\tmp0j2itigw\quandl\2023-11-27T18;14;15.329867\adjustments.sqlite -> C:\Users\justu\.zipline\data\quandl\2023-11-27T18;14;15.329867
# [2023-11-27T19:16:25+0100-INFO][root]
#  copying C:\Users\justu\AppData\Local\Temp\tmppz6poify\tmp0j2itigw\quandl\2023-11-27T18;14;15.329867\assets-7.sqlite -> C:\Users\justu\.zipline\data\quandl\2023-11-27T18;14;15.329867
# [2023-11-27T19:16:25+0100-INFO][root]
#  creating C:\Users\justu\.zipline\data\quandl\2023-11-27T18;14;15.329867\daily_equities.bcol
() has to be called with the same params
#     # from above and returns a pandas dataframe.
#     short_mavg = data.history(context.asset, 'price', bar_count=100, frequency="1d").mean()
#     long_mavg = data.history(context.asset, 'price', bar_count=300, frequency="1d").mean()
#
#     # Trading logic
#     if short_mavg > long_mavg:
#         # order_target orders as many shares as needed to
#         # achieve the desired number of shares.
#         order_target(context.asset, 100)
#     elif short_mavg < long_mavg:
#         order_target(context.asset, 0)
#
#     # Save values for later inspection
#     record(AAPL=data.current(context.asset, 'price'),
#            short_mavg=short_mavg,
#            long_mavg=long_mavg)
#
#
# def analyze(context, perf):
#     fig = plt.figure()
#     ax1 = fig.add_subplot(211)
#     perf.portfolio_value.plot(ax=ax1)
#     ax1.set_ylabel('portfolio value in $')
#
#     ax2 = fig.add_subplot(212)
#     perf['AAPL'].plot(ax=ax2)
#     perf[['short_mavg', 'long_mavg']].plot(ax=ax2)
#
#     perf_trans = perf.loc[[t != [] for t in perf.transactions]]
#     buys = perf_trans.loc[[t[0]['amount'] > 0 for t in perf_trans.transactions]]
#     sells = perf_trans.loc[
#         [t[0]['amount'] < 0 for t in perf_trans.transactions]]
#     ax2.plot(buys.index, perf.short_mavg.loc[buys.index],
#              '^', markersize=10, color='m')
#     ax2.plot(sells.index, perf.short_mavg.loc[sells.index],
#              'v', markersize=10, color='k')
#     ax2.set_ylabel('price in $')
#     plt.legend(loc=0)
#     plt.tight_layout()
# Out:
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
# ...
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
#                                         period_open              period_close  \
# 2014-01-02 21:00:00+00:00 2014-01-02 14:31:00+00:00 2014-01-02 21:00:00+00:00
# 2014-01-03 21:00:00+00:00 2014-01-03 14:31:00+00:00 2014-01-03 21:00:00+00:00
# 2014-01-06 21:00:00+00:00 2014-01-06 14:31:00+00:00 2014-01-06 21:00:00+00:00
# 2014-01-07 21:00:00+00:00 2014-01-07 14:31:00+00:00 2014-01-07 21:00:00+00:00
# 2014-01-08 21:00:00+00:00 2014-01-08 14:31:00+00:00 2014-01-08 21:00:00+00:00
# ...                                             ...                       ...
# 2017-12-22 21:00:00+00:00 2017-12-22 14:31:00+00:00 2017-12-22 21:00:00+00:00
# 2017-12-26 21:00:00+00:00 2017-12-26 14:31:00+00:00 2017-12-26 21:00:00+00:00
# 2017-12-27 21:00:00+00:00 2017-12-27 14:31:00+00:00 2017-12-27 21:00:00+00:00
# 2017-12-28 21:00:00+00:00 2017-12-28 14:31:00+00:00 2017-12-28 21:00:00+00:00
# 2017-12-29 21:00:00+00:00 2017-12-29 14:31:00+00:00 2017-12-29 21:00:00+00:00
#
#                            net_leverage  starting_exposure  ending_exposure  \
# 2014-01-02 21:00:00+00:00      0.000000                0.0              0.0
# 2014-01-03 21:00:00+00:00      0.000000                0.0              0.0
# 2014-01-06 21:00:00+00:00      0.000000                0.0              0.0
# 2014-01-07 21:00:00+00:00      0.000000                0.0              0.0
# 2014-01-08 21:00:00+00:00      0.000000                0.0              0.0
# ...                                 ...                ...              ...
# 2017-12-22 21:00:00+00:00      0.001749            17501.0          17501.0
# 2017-12-26 21:00:00+00:00      0.001705            17501.0          17057.0
# 2017-12-27 21:00:00+00:00      0.001705            17057.0          17060.0
# 2017-12-28 21:00:00+00:00      0.001710            17060.0          17108.0
# 2017-12-29 21:00:00+00:00      0.001692            17108.0          16923.0
# 2017-12-28 21:00:00+00:00                 0.000484         0.000192
# 2017-12-29 21:00:00+00:00                 0.000466         0.000193
#
#                            benchmark_period_return  benchmark_volatility  \
# 2014-01-02 21:00:00+00:00                      0.0                   NaN
# 2014-01-03 21:00:00+00:00                      0.0                   0.0
# 2014-01-06 21:00:00+00:00                      0.0                   0.0
# 2014-01-07 21:00:00+00:00                      0.0                   0.0
# 2014-01-08 21:00:00+00:00                      0.0                   0.0
# ...                                            ...                   ...
# 2017-12-22 21:00:00+00:00                      0.0                   0.0
# 2017-12-26 21:00:00+00:00                      0.0                   0.0
# 2017-12-27 21:00:00+00:00                      0.0                   0.0
# 2017-12-28 21:00:00+00:00                      0.0                   0.0
# 2017-12-29 21:00:00+00:00                      0.0                   0.0
#
#                              AAPL  short_mavg   long_mavg
# 2014-01-02 21:00:00+00:00     NaN         NaN         NaN
# 2014-01-03 21:00:00+00:00     NaN         NaN         NaN
# 2014-01-06 21:00:00+00:00     NaN         NaN         NaN
# 2014-01-07 21:00:00+00:00     NaN         NaN         NaN
# 2014-01-08 21:00:00+00:00     NaN         NaN         NaN
# ...                           ...         ...         ...
# 2017-12-22 21:00:00+00:00  175.01  163.442190  142.891860
# 2017-12-26 21:00:00+00:00  170.57  163.598280  143.075387
# 2017-12-27 21:00:00+00:00  170.60  163.746503  143.259273
# 2017-12-28 21:00:00+00:00  171.08  163.899520  143.445907
# 2017-12-29 21:00:00+00:00  169.23  163.997280  143.626570
#
# [1007 rows x 40 columns]

# %%
# %%zipline --start 2014-1-1 --end 2018-1-1 -o dma.pickle --no-benchmark
#
#
# from zipline.api import order_target, record, symbol
# import matplotlib.pyplot as plt
#
# def initialize(context):
#     context.i = 0
#     context.asset = symbol('AAPL')
#
#
# def handle_data(context, data):
#     # Skip first 300 days to get full windows
#     context.i += 1
#     if context.i < 300:
#         return
#
#     # Compute averages
#     # data.history() has to be called with the same params
#     # from above and returns a pandas dataframe.
#     short_mavg = data.history(context.asset, 'price', bar_count=100, frequency="1d").mean()
#     long_mavg = data.history(context.asset, 'price', bar_count=300, frequency="1d").mean()
#
#     # Trading logic
#     if short_mavg > long_mavg:
#         # order_target orders as many shares as needed to
#         # achieve the desired number of shares.
#         order_target(context.asset, 100)
#     elif short_mavg < long_mavg:
#         order_target(context.asset, 0)
#
#     # Save values for later inspection
#     record(AAPL=data.current(context.asset, 'price'),
#            short_mavg=short_mavg,
#            long_mavg=long_mavg)
#
#
# def analyze(context, perf):
#     fig = plt.figure()
#     ax1 = fig.add_subplot(211)
#     perf.portfolio_value.plot(ax=ax1)
#     ax1.set_ylabel('portfolio value in $')
#
#     ax2 = fig.add_subplot(212)
#     perf['AAPL'].plot(ax=ax2)
#     perf[['short_mavg', 'long_mavg']].plot(ax=ax2)
#
#     perf_trans = perf.loc[[t != [] for t in perf.transactions]]
#     buys = perf_trans.loc[[t[0]['amount'] > 0 for t in perf_trans.transactions]]
#     sells = perf_trans.loc[
#         [t[0]['amount'] < 0 for t in perf_trans.transactions]]
#     ax2.plot(buys.index, perf.short_mavg.loc[buys.index],
#              '^', markersize=10, color='m')
#     ax2.plot(sells.index, perf.short_mavg.loc[sells.index],
#              'v', markersize=10, color='k')
#     ax2.set_ylabel('price in $')
#     plt.legend(loc=0)
#     plt.show()
# Out:
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\data\data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# D:\Install\mambaforge-pypy3\envs\AlgoTradingVenv\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
[{'sid': Equity(8 [AAPL]), 'amount': 100, 'cos...
# 2017-12-29 21:00:00+00:00  [{'sid': Equity(8 [AAPL]), 'amount': 100, 'cos...
#
#                            short_exposure  shorts_count  ending_exposure  ...  \
# 2014-01-02 21:00:00+00:00             0.0             0              0.0  ...
# 2014-01-03 21:00:00+00:00             0.0             0              0.0  ...
# 2014-01-06 21:00:00+00:00             0.0             0              0.0  ...
# 2014-01-07 21:00:00+00:00             0.0             0              0.0  ...
# 2014-01-08 21:00:00+00:00             0.0             0              0.0  ...
# ...                                   ...           ...              ...  ...
# 2017-12-22 21:00:00+00:00             0.0             0          17501.0  ...
# 2017-12-26 21:00:00+00:00             0.0             0          17057.0  ...
# 2017-12-27 21:00:00+00:00             0.0             0          17060.0  ...
# 2017-12-28 21:00:00+00:00             0.0             0          17108.0  ...
# 2017-12-29 21:00:00+00:00             0.0             0          16923.0  ...
#
#                            alpha  beta  max_leverage treasury_period_return  \
# 2014-01-02 21:00:00+00:00   None  None      0.000000                    0.0
# 2014-01-03 21:00:00+00:00   None  None      0.000000                    0.0
# 2014-01-06 21:00:00+00:00   None  None      0.000000                    0.0
# 2014-01-07 21:00:00+00:00   None  None      0.000000                    0.0
# 2014-01-08 21:00:00+00:00   None  None      0.000000                    0.0
# ...                          ...   ...           ...                    ...
# 2017-12-22 21:00:00+00:00   None  None      0.001763                    0.0
# 2017-12-26 21:00:00+00:00   None  None      0.001763                    0.0
# 2017-12-27 21:00:00+00:00   None  None      0.001763                    0.0
# 2017-12-28 21:00:00+00:00   None  None      0.001763                    0.0
# 2017-12-29 21:00:00+00:00   None  None      0.001763                    0.0
#
#                            algorithm_period_return  max_drawdown  \
# 2014-01-02 21:00:00+00:00                 0.000000      0.000000
# 2014-01-03 21:00:00+00:00                 0.000000      0.000000
# 2014-01-06 21:00:00+00:00                 0.000000      0.000000
# 2014-01-07 21:00:00+00:00                 0.000000      0.000000
# 2014-01-08 21:00:00+00:00                 0.000000      0.000000
# ...                                            ...           ...
# 2017-12-22 21:00:00+00:00                 0.000524     -0.000295
# 2017-12-26 21:00:00+00:00                 0.000479     -0.000295
# 2017-12-27 21:00:00+00:00                 0.000480     -0.000295
# 2017-12-28 21:00:00+00:00                 0.000484     -0.000295
# 2017-12-29 21:00:00+00:00                 0.000466     -0.000295
#
#                            algo_volatility    AAPL  short_mavg   long_mavg
# 2014-01-02 21:00:00+00:00              NaN     NaN         NaN         NaN
# 2014-01-03 21:00:00+00:00         0.000000     NaN         NaN         NaN
# 2014-01-06 21:00:00+00:00         0.000000     NaN         NaN         NaN
# 2014-01-07 21:00:00+00:00         0.000000     NaN         NaN         NaN
# 2014-01-08 21:00:00+00:00         0.000000     NaN         NaN         NaN
# ...                                    ...     ...         ...         ...
# 2017-12-22 21:00:00+00:00         0.000191  175.01  163.442190  142.891860
# 2017-12-26 21:00:00+00:00         0.000193  170.57  163.598280  143.075387
# 2017-12-27 21:00:00+00:00         0.000192  170.60  163.746503  143.259273
# 2017-12-28 21:00:00+00:00         0.000192  171.08  163.899520  143.445907
# 2017-12-29 21:00:00+00:00         0.000193  169.23  163.997280  143.626570
#
# [1007 rows x 40 columns]
